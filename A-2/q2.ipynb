# %% [markdown]
# <a href="https://colab.research.google.com/github/azan6155/24K-5638/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
datalist = []

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f11695b0-1c26-4938-8cfd-5e4727280f30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f11695b0-1c26-4938-8cfd-5e4727280f30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68734efc-5848-4305-8318-da94491b132c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68734efc-5848-4305-8318-da94491b132c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("sensor_data.csv") as file:
    for line in file:
        row = line.strip().split(",")
        datalist.append(row)

# %%
data = np.array(datalist , dtype=float)

# %%
data[data == -999] = np.nan
data[data < 0] = np.nan
data[data > 100] = np.nan

# %%
sensorMeans = np.nanmean(data,axis=0)

# %%
hourMedian = np.nanmedian(data, axis=1)

# %%
nanCounts = np.isnan(data).sum(axis=0)

# %%
worstSensorIndex = np.argmax(nanCounts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3590466873.py in <cell line: 0>()
# ----> 1 worstSensorIndex = np.argmax(nanCounts)
#
# NameError: name 'nanCounts' is not defined

# %%
normalized = (data-globalMin) / (globalMax-globalMin)

# %%
np.savetxt("sensor_data_normalized.csv", normalized,delimiter=",")

# %%
import pandas as pd

df = pd.read_csv("sensor_data_normalized.csv")
print(df)
# Out:
#      1.401249999999999996e-01  7.107499999999999929e-01  \
# 0                    0.465500                  0.771250
# 1                    0.363375                  0.148125
# 2                    0.574875                  0.840000
# 3                    0.834250                  0.776375
# 4                    0.986000                  0.262625
# ..                        ...                       ...
# 714                  0.771375                  0.018875
# 715                  0.265625                  0.529375
# 716                  0.107500                  0.686125
# 717                  0.150375                  0.415750
# 718                  0.438250                       NaN
#
#      4.716249999999999609e-01  9.070000000000000284e-01  \
# 0                    0.730500                  0.017750
# 1                    0.273250                  0.536000
# 2                    0.453625                  0.040875
# 3                         NaN                  0.214500
# ...
