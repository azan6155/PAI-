# %% [markdown]
# <a href="https://colab.research.google.com/github/azan6155/24K-5638/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# %%
def main():
    try:
        with open("api.txt") as f:
            apiURL = f.read().strip()
    except FileNotFoundError:
        print("ERROR : could not find api.txt")
        return

    try:
        response = requests.get(apiURL , timeout=10)
    except requests.exceptions.RequestException:
        print("ERROR: Network failure. Please check your internet connection.")
        return

    if response.status_code != 200:
        print("HTTP ERROR:", response.status_code)
        print("Details:", response.text)
        return

    try:
        data = response.json()
    except json.JSONDecodeError:
        print("ERROR: Could not decode JSON from API.")
        return

    print("\nAPI SUMMARY\n")
    for key,value in data.items():
        if key not in ["data"]:
            print(f"{key}:{value}")

    if data.get("status") != "success":
        print("\nAPI FAILURE:", data.get("reason", "Unknown error"))
        return

    if "data" not in data or not data["data"]:
        print("\nERROR: API returned empty match data.")
        return

    matches = data["data"]

    print("\nLIVE MATCH SUMMARY \n")

    for match in matches:
        print("Match Name :", match.get("name", "N/A"))
        print("Status     :", match.get("status", "N/A"))
        print("Venue      :", match.get("venue", "N/A"))
        print("Date       :", match.get("date", "N/A"))

        if "score" in match and match["score"]:
            print("\n  --- SCORECARD ---")
            for inning in match["score"]:
                print(f"\n  Inning : {inning.get('inning', 'N/A')}")
                print(f"  Runs   : {inning.get('r', 'N/A')}")
                print(f"  Wkts   : {inning.get('w', 'N/A')}")
                print(f"  Overs  : {inning.get('o', 'N/A')}")
        else:
            print("No Score Data Available.")

# %%
main()
# Out:
# API SUMMARY
#
# apikey:e88f7b40-b7e1-40df-a2cf-4132793fb2c5
# status:success
# info:{'hitsToday': 1, 'hitsUsed': 1, 'hitsLimit': 100, 'credits': 0, 'server': 8, 'offsetRows': 0, 'totalRows': 26, 'queryTime': 37.9952, 's': 0, 'cache': 1}
#
# LIVE MATCH SUMMARY
#
# Match Name : Thailand Women vs Papua New Guinea Women, 6th Match
# Status     : Thailand Women won by 7 wkts
# Venue      : Terdthai Cricket Ground, Bangkok
# Date       : 2025-11-17
#
#   --- SCORECARD ---
#
#   Inning : papua new guinea women Inning 1
#   Runs   : 109
#   Wkts   : 4
#   Overs  : 20
#
#   Inning : Thailand Women,Papua New Guinea Women Inning 1
#   Runs   : 110
#   Wkts   : 3
#   Overs  : 19
# Match Name : Scotland Women vs Namibia Women, 5th Match
# Status     : Scotland Women won by 7 wkts
# Venue      : Terdthai Cricket Ground, Bangkok
# Date       : 2025-11-17
#
#   --- SCORECARD ---
#
#   Inning : namibia women Inning 1
#   Runs   : 81
#   Wkts   : 9
#   Overs  : 20
#
#   Inning : Scotland Women,Namibia Women Inning 1
#   Runs   : 82
#   Wkts   : 3
#   Overs  : 14.2
# Match Name : Pakistan vs Zimbabwe, 1st Match
# Status     : Pakistan need 119 runs in 88 balls
# Venue      : Rawalpindi Cricket Stadium, Rawalpindi
# Date       : 2025-11-17
#
#   --- SCORECARD ---
#
#   Inning : Zimbabwe Inning 1
#   Runs   : 147
#   Wkts   : 8
#   Overs  : 20
#
#   Inning : Pakistan Inning 1
#   Runs   : 29
#   Wkts   : 2
#   Overs  : 5.2
# Match Name : Hobart Hurricanes Women vs Adelaide Strikers Women, 14th Match
# Status     : Hobart Hurricanes Women won by 4 wkts
# Venue      : Bellerive Oval, Hobart
# Date       : 2025-11-18
#
#   --- SCORECARD ---
#
#   Inning : Adelaide Strikers Women Inning 1
#   Runs   : 134
#   Wkts   : 7
#   Overs  : 20
#
#   Inning : Hobart Hurricanes Women Inning 1
#   Runs   : 136
#   Wkts   : 6
#   Overs  : 19.4
# Match Name : Canterbury vs Northern Knights, 3rd Match
# Status     : Day 1: Stumps - Canterbury trail by 193 runs
# Venue      : Mainpower Oval, Rangiora
# Date       : 2025-11-17
#
#   --- SCORECARD ---
#
#   Inning : Northern Knights Inning 1
#   Runs   : 237
#   Wkts   : 10
#   Overs  : 77.5
#
#   Inning : Canterbury Inning 1
#   Runs   : 44
#   Wkts   : 1
#   Overs  : 16
# Match Name : Wellington vs Otago, 2nd Match
# Status     : Day 1: Stumps - Wellington opt to bowl
# Venue      : Basin Reserve, Wellington
# Date       : 2025-11-17
#
#   --- SCORECARD ---
#
#   Inning : Otago Inning 1
#   Runs   : 428
#   Wkts   : 4
#   Overs  : 97
# Match Name : Central Districts vs Auckland, 1st Match
# Status     : Day 1: Stumps - Auckland opt to bat
# Venue      : Fitzherbert Park, Palmerston North
# Date       : 2025-11-17
#
#   --- SCORECARD ---
#
#   Inning : auckland Inning 1
#   Runs   : 393
#   Wkts   : 7
#   Overs  : 96
# Match Name : Sikkim vs Arunachal Pradesh, Plate
# Status     : Sikkim won by an innings and 319 runs
# Venue      : SICA ground, Rangpo
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : arunachal pradesh Inning 1
#   Runs   : 91
#   Wkts   : 10
#   Overs  : 27.2
#
#   Inning : Sikkim,Arunachal Pradesh Inning 1
#   Runs   : 514
#   Wkts   : 7
#   Overs  : 121.1
#
#   Inning : arunachal pradesh Inning 2
#   Runs   : 104
#   Wkts   : 10
#   Overs  : 44.3
# Match Name : Manipur vs Meghalaya, Plate
# Status     : Day 3: Stumps - Meghalaya lead by 137 runs
# Venue      : Pithwala Stadium, Bhimpore, Surat
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : meghalaya Inning 1
#   Runs   : 430
#   Wkts   : 10
#   Overs  : 115.4
#
#   Inning : Manipur,Meghalaya Inning 1
#   Runs   : 342
#   Wkts   : 10
#   Overs  : 126.3
#
#   Inning : meghalaya Inning 2
#   Runs   : 49
#   Wkts   : 1
#   Overs  : 17
# Match Name : Bihar vs Mizoram, Plate
# Status     : Day 3: Stumps - Bihar lead by 13 runs
# Venue      : Moin-ul-Haq Stadium, Patna
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : Mizoram Inning 1
#   Runs   : 509
#   Wkts   : 10
#   Overs  : 136.5
#
#   Inning : Bihar Inning 1
#   Runs   : 522
#   Wkts   : 10
#   Overs  : 136.3
# Match Name : Karnataka vs Chandigarh, Elite Group B
# Status     : Day 3: 3rd Session - Karnataka won by an innings and 185 runs
# Venue      : KSCA Hubli Cricket Ground, Hubli
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : karnataka Inning 1
#   Runs   : 547
#   Wkts   : 8
#   Overs  : 160
#
#   Inning : Karnataka,Chandigarh Inning 1
#   Runs   : 222
#   Wkts   : 10
#   Overs  : 63.2
#
#   Inning : karnataka Inning 2
#   Runs   : 140
#   Wkts   : 10
#   Overs  : 33.5
# Match Name : Rajasthan vs Delhi, Elite Group D
# Status     : Day 3: Stumps - Delhi trail by 274 runs
# Venue      : Madan Paliwal Miraj Sports Centre, Rajsamand, Rajasthan
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : Rajasthan Inning 1
#   Runs   : 570
#   Wkts   : 7
#   Overs  : 161
#
#   Inning : Delhi Inning 1
#   Runs   : 296
#   Wkts   : 10
#   Overs  : 92.2
# Match Name : Jammu and Kashmir vs Hyderabad, Elite Group D
# Status     : Day 3: Stumps - Hyderabad need 303 runs
# Venue      : Hostel Ground JKCA, Jammu
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : Jammu and Kashmir Inning 1
#   Runs   : 170
#   Wkts   : 10
#   Overs  : 47.1
#
#   Inning : Hyderabad Inning 1
#   Runs   : 121
#   Wkts   : 10
#   Overs  : 39.2
#
#   Inning : Jammu and Kashmir Inning 2
#   Runs   : 422
#   Wkts   : 10
#   Overs  : 101.5
#
#   Inning : Hyderabad Inning 2
#   Runs   : 169
#   Wkts   : 7
#   Overs  : 52.3
# Match Name : Mumbai vs Puducherry, Elite Group D
# Status     : Day 3: Stumps - Puducherry trail by 267 runs
# Venue      : Sharad Pawar Cricket Academy BKC, Mumbai
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : Mumbai Inning 1
#   Runs   : 630
#   Wkts   : 5
#   Overs  : 147
#
#   Inning : Puducherry Inning 1
#   Runs   : 132
#   Wkts   : 10
#   Overs  : 47.2
#
#   Inning : Mumbai Inning 2
#   Runs   : 231
#   Wkts   : 6
#   Overs  : 45
# Match Name : Haryana vs Services, Elite Group C
# Status     : Day 3: Stumps - Haryana need 242 runs
# Venue      : Ch Bansi Lal Cricket Stadium, Rohtak
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : Services Inning 1
#   Runs   : 205
#   Wkts   : 10
#   Overs  : 75.5
#
#   Inning : Haryana Inning 1
#   Runs   : 111
#   Wkts   : 10
#   Overs  : 43.2
#
#   Inning : Services Inning 2
#   Runs   : 283
#   Wkts   : 7
#   Overs  : 108
#
#   Inning : Haryana Inning 2
#   Runs   : 136
#   Wkts   : 6
#   Overs  : 34
# Match Name : Bengal vs Assam, Elite Group C
# Status     : Day 3: Stumps - Assam trail by 144 runs
# Venue      : Bengal Cricket Academy Ground, Kalyani
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : assam Inning 1
#   Runs   : 200
#   Wkts   : 10
#   Overs  : 80.2
#
#   Inning : Bengal,Assam Inning 1
#   Runs   : 442
#   Wkts   : 10
#   Overs  : 109.1
#
#   Inning : assam Inning 2
#   Runs   : 98
#   Wkts   : 3
#   Overs  : 38
# Match Name : Uttarakhand vs Gujarat, Elite Group C
# Status     : Day 3: Stumps - Uttarakhand need 301 runs
# Venue      : Abhimanyu Cricket Academy, Dehradun
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : Gujarat Inning 1
#   Runs   : 324
#   Wkts   : 8
#   Overs  : 88.4
#
#   Inning : Uttarakhand Inning 1
#   Runs   : 272
#   Wkts   : 10
#   Overs  : 74.3
#
#   Inning : Gujarat Inning 2
#   Runs   : 291
#   Wkts   : 5
#   Overs  : 66.3
#
#   Inning : Uttarakhand Inning 2
#   Runs   : 43
#   Wkts   : 0
#   Overs  : 15
# Match Name : Railways vs Tripura, Elite Group C
# Status     : Railways won by an innings and 117 runs
# Venue      : Sardar Vallabhai Patel Stadium, Valsad
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : tripura Inning 1
#   Runs   : 136
#   Wkts   : 10
#   Overs  : 41
#
#   Inning : Railways,Tripura Inning 1
#   Runs   : 446
#   Wkts   : 9
#   Overs  : 127
#
#   Inning : tripura Inning 2
#   Runs   : 193
#   Wkts   : 10
#   Overs  : 68.3
# Match Name : Tamil Nadu vs Uttar Pradesh, Elite Group A
# Status     : Day 3: Stumps - Uttar Pradesh trail by 116 runs
# Venue      : Sri Ramakrishna College of Arts and Science Ground, Coimbatore
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : tamil nadu Inning 1
#   Runs   : 455
#   Wkts   : 10
#   Overs  : 136.3
#
#   Inning : Tamil Nadu,Uttar Pradesh Inning 1
#   Runs   : 339
#   Wkts   : 6
#   Overs  : 113
# Match Name : Madhya Pradesh vs Kerala, Elite Group B
# Status     : Day 3: Stumps - Kerala lead by 315 runs
# Venue      : Holkar Cricket Stadium, Indore
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : Kerala Inning 1
#   Runs   : 281
#   Wkts   : 10
#   Overs  : 114.4
#
#   Inning : Madhya Pradesh Inning 1
#   Runs   : 192
#   Wkts   : 10
#   Overs  : 77.1
#
#   Inning : Kerala Inning 2
#   Runs   : 226
#   Wkts   : 3
#   Overs  : 64
# Match Name : Saurashtra vs Goa, Elite Group B
# Status     : Day 3: Stumps - Goa trail by 150 runs
# Venue      : Saurashtra Cricket Association Stadium C, Rajkot
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : saurashtra Inning 1
#   Runs   : 585
#   Wkts   : 7
#   Overs  : 150
#
#   Inning : Saurashtra,Goa Inning 1
#   Runs   : 358
#   Wkts   : 10
#   Overs  : 106.2
#
#   Inning : saurashtra Inning 2
#   Runs   : 77
#   Wkts   : 2
#   Overs  : 16.3
# Match Name : Punjab vs Maharashtra, Elite Group B
# Status     : Day 3: 2nd Session - Punjab trail by 124 runs
# Venue      : Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur, New Chandigarh
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : Maharashtra Inning 1
#   Runs   : 350
#   Wkts   : 10
#   Overs  : 113.3
#
#   Inning : Punjab Inning 1
#   Runs   : 151
#   Wkts   : 10
#   Overs  : 58.4
#
#   Inning : Maharashtra Inning 2
#   Runs   : 75
#   Wkts   : 6
#   Overs  : 28
# Match Name : Vidarbha vs Baroda, Elite Group A
# Status     : Day 3: Stumps - Baroda need 203 runs
# Venue      : Vidarbha Cricket Association Stadium, Nagpur
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : vidarbha Inning 1
#   Runs   : 169
#   Wkts   : 10
#   Overs  : 58
#
#   Inning : Vidarbha,Baroda Inning 1
#   Runs   : 166
#   Wkts   : 10
#   Overs  : 72.2
#
#   Inning : vidarbha Inning 2
#   Runs   : 272
#   Wkts   : 10
#   Overs  : 98.2
#
#   Inning : Vidarbha,Baroda Inning 2
#   Runs   : 73
#   Wkts   : 5
#   Overs  : 32
# Match Name : Odisha vs Nagaland, Elite Group A
# Status     : Day 3: Stumps - Nagaland need 424 runs
# Venue      : KIIT Stadium, Bhubaneswar
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : odisha Inning 1
#   Runs   : 275
#   Wkts   : 10
#   Overs  : 104.4
#
#   Inning : Odisha,Nagaland Inning 1
#   Runs   : 161
#   Wkts   : 10
#   Overs  : 57.3
#
#   Inning : odisha Inning 2
#   Runs   : 350
#   Wkts   : 5
#   Overs  : 71
#
#   Inning : Odisha,Nagaland Inning 2
#   Runs   : 41
#   Wkts   : 1
#   Overs  : 18
# Match Name : Jharkhand vs Andhra, Elite Group A
# Status     : Day 3: Stumps - Jharkhand trail by 205 runs
# Venue      : Keenan Stadium, Jamshedpur
# Date       : 2025-11-16
#
#   --- SCORECARD ---
#
#   Inning : jharkhand Inning 1
#   Runs   : 328
#   Wkts   : 10
#   Overs  : 112.3
#
#   Inning : Jharkhand,Andhra Inning 1
#   Runs   : 567
#   Wkts   : 6
#   Overs  : 128
#
#   Inning : jharkhand Inning 2
#   Runs   : 34
#   Wkts   : 2
#   Overs  : 15
